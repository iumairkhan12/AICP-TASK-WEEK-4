# %%
import math

class Hexagon:
    def _init_(self, side_length):
        self.side_length = side_length

    def calc_area(self):
        return 1.5 * 1.732 * self.side_length

    def calc_peri(self):
        return 6 * self.side_length

    def calc_angle_sum(self):
        return 6 * 120

    def display(self):
        print("Area of hexagon is:", self.calc_area())
        print("Perimeter of hexagon is:", self.calc_peri())
        print("Sum of angles of hexagon is:", self.calc_angle_sum())

class Square:
    def _init_(self, side_length):
        self.side_length = side_length

    def calc_area_square(self):
        return self.side_length ** 2

    def calc_peri_square(self):
        return 4 * self.side_length

    def display(self):
        print("Area of square is:", self.calc_area_square())
        print("Perimeter of square is:", self.calc_peri_square())

def main():
    cnic_last_digit = int(input("Enter the last digit of your CNIC: "))
    
    hexagon = Hexagon(cnic_last_digit)
    square = Square(cnic_last_digit + 1)

    while True:
        print("\nEnter 1 to calculate area, perimeter, and sum of angles of hexagon")
        print("Enter 2 to calculate area and perimeter of square")
        print("Press any other key to exit")

        choice = input()

        if choice == '1':
            hexagon.display()
        elif choice == '2':
            square.display()
        else:
            break

if _name_ == "_main_":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 55
#      52         else:
#      53             break
# ---> 55 if _name_ == "_main_":
#      56     main()
#
# NameError: name '_name_' is not defined

# %%
import math

class Hexagon:
    def __init__(self, side_length):
        self.side_length = side_length

    def calc_area(self):
        return 1.5 * 1.732 * self.side_length

    def calc_peri(self):
        return 6 * self.side_length

    def calc_angle_sum(self):
        return 6 * 120

    def display(self):
        print("Area of hexagon is:", self.calc_area())
        print("Perimeter of hexagon is:", self.calc_peri())
        print("Sum of angles of hexagon is:", self.calc_angle_sum())

class Square:
    def __init__(self, side_length):
        self.side_length = side_length

    def calc_area_square(self):
        return self.side_length ** 2

    def calc_peri_square(self):
        return 4 * self.side_length

    def display(self):
        print("Area of square is:", self.calc_area_square())
        print("Perimeter of square is:", self.calc_peri_square())

def main():
    cnic_last_digit = int(input("Enter the last digit of your CNIC: "))
    
    hexagon = Hexagon(cnic_last_digit)
    square = Square(cnic_last_digit + 1)

    while True:
        print("\nEnter 1 to calculate area, perimeter, and sum of angles of hexagon")
        print("Enter 2 to calculate area and perimeter of square")
        print("Press any other key to exit")

        choice = input()

        if choice == '1':
            hexagon.display()
        elif choice == '2':
            square.display()
        else:
            break

if __name__ == "__main__":
    main()
# Out:
# Enter the last digit of your CNIC: 8431
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 1
# Area of hexagon is: 21903.737999999998
# Perimeter of hexagon is: 50586
# Sum of angles of hexagon is: 720
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 2
# Area of square is: 71098624
# Perimeter of square is: 33728
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# s

# %%
import math

class Student:
    def _init_(self, student_id):
        self.student_id = student_id

class Hexagon:
    def _init_(self, side_length):
        self.side_length = side_length

    def calcArea(self):
        return 1.5 * 1.732 * self.side_length

    def calcPeri(self):
        return 6 * self.side_length

    def calcAngleSum(self):
        return 6 * 120

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of hexagon is:", self.calcArea())
        print("Perimeter of hexagon is:", self.calcPeri())
        print("Sum of angles of hexagon is:", self.calcAngleSum())

class Square:
    def _init_(self, side_length):
        self.side_length = side_length

    def calcAreaSquare(self):
        return self.side_length ** 2

    def calcPeriSquare(self):
        return 4 * self.side_length

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of square is:", self.calcAreaSquare())
        print("Perimeter of square is:", self.calcPeriSquare())

def main():
    student_id = "XY12345678"  # Replace this with your actual student ID
    cnic_last_digit = int(input("Enter the last digit of your CNIC: "))
    
    hexagon = Hexagon(cnic_last_digit)
    square = Square(cnic_last_digit + 1)

    while True:
        print("\nEnter 1 to calculate area, perimeter, and sum of angles of hexagon")
        print("Enter 2 to calculate area and perimeter of square")
        print("Press any other key to exit")

        choice = input()

        if choice == '1':
            hexagon.display(student_id)
        elif choice == '2':
            square.display(student_id)
        else:
            break

if _name_ == "_main_":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 62
#      59         else:
#      60             break
# ---> 62 if _name_ == "_main_":
#      63     main()
#
# NameError: name '_name_' is not defined

# %%
import math

class Student:
    def __init__(self, student_id):
        self.student_id = student_id

class Hexagon:
    def __init__(self, side_length):
        self.side_length = side_length

    def calcArea(self):
        return 1.5 * 1.732 * self.side_length

    def calcPeri(self):
        return 6 * self.side_length

    def calcAngleSum(self):
        return 6 * 120

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of hexagon is:", self.calcArea())
        print("Perimeter of hexagon is:", self.calcPeri())
        print("Sum of angles of hexagon is:", self.calcAngleSum())

class Square:
    def __init__(self, side_length):
        self.side_length = side_length

    def calcAreaSquare(self):
        return self.side_length ** 2

    def calcPeriSquare(self):
        return 4 * self.side_length

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of square is:", self.calcAreaSquare())
        print("Perimeter of square is:", self.calcPeriSquare())

def main():
    student_id = "Umair321"  # Replace this with your actual student ID
    cnic_last_digit = int(input("Enter the last digit of your CNIC: "))
    
    hexagon = Hexagon(cnic_last_digit)
    square = Square(cnic_last_digit + 1)

    while True:
        print("\nEnter 1 to calculate area, perimeter, and sum of angles of hexagon")
        print("Enter 2 to calculate area and perimeter of square")
        print("Press any other key to exit")

        choice = input()

        if choice == '1':
            hexagon.display(student_id)
        elif choice == '2':
            square.display(student_id)
        else:
            break

if __name__ == "__main__":
    main()
# Out:
# Enter the last digit of your CNIC: 8431
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 2
#
# Student ID is: XY12345678
# Area of square is: 71098624
# Perimeter of square is: 33728
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# e

# %%
import math

class Student:
    def __init__(self, student_id):
        self.student_id = student_id

class Hexagon:
    def __init__(self, side_length):
        self.side_length = side_length

    def calcArea(self):
        return 1.5 * 1.732 * self.side_length

    def calcPeri(self):
        return 6 * self.side_length

    def calcAngleSum(self):
        return 6 * 120

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of hexagon is:", self.calcArea())
        print("Perimeter of hexagon is:", self.calcPeri())
        print("Sum of angles of hexagon is:", self.calcAngleSum())

class Square:
    def __init__(self, side_length):
        self.side_length = side_length

    def calcAreaSquare(self):
        return self.side_length ** 2

    def calcPeriSquare(self):
        return 4 * self.side_length

    def display(self, student_id):
        print(f"\nStudent ID is: {student_id}")
        print("Area of square is:", self.calcAreaSquare())
        print("Perimeter of square is:", self.calcPeriSquare())

def main():
    student_id = "Umair321"  # Replace this with your actual student ID
    cnic_last_digit = int(input("Enter the last digit of your CNIC: "))
    
    hexagon = Hexagon(cnic_last_digit)
    square = Square(cnic_last_digit + 1)

    while True:
        print("\nEnter 1 to calculate area, perimeter, and sum of angles of hexagon")
        print("Enter 2 to calculate area and perimeter of square")
        print("Press any other key to exit")

        choice = input()

        if choice == '1':
            hexagon.display(student_id)
        elif choice == '2':
            square.display(student_id)
        else:
            break

if __name__ == "__main__":
    main()
# Out:
# Enter the last digit of your CNIC: 8431
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 1
#
# Student ID is: Umair321
# Area of hexagon is: 21903.737999999998
# Perimeter of hexagon is: 50586
# Sum of angles of hexagon is: 720
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 2
#
# Student ID is: Umair321
# Area of square is: 71098624
# Perimeter of square is: 33728
#
# Enter 1 to calculate area, perimeter, and sum of angles of hexagon
# Enter 2 to calculate area and perimeter of square
# Press any other key to exit
# 4
